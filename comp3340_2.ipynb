# %%
# !unzip -qq COMP3340-main.zip

# %%
# %cd COMP3340-main
# Out:
# /content/COMP3340-main

# %%
# !cp "/content/drive/MyDrive/COMP3340/data.zip" "CNN_Image_Classification_Code/"

# %%
# !unzip -qq CNN_Image_Classification_Code/data.zip -d CNN_Image_Classification_Code/CNN_Image_Classification_Code

# %%
# !pip install -U openmim
# !mim install mmcv\==1.5.0
# !pip install yapf\==0.40.1

# %cd CNN_Image_Classification_Code/CNN_Image_Classification_Code
# !pip install -e .
# %cd ..
# %cd ..
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 35.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 59.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !bash trainVGG.sh
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/cnn/bricks/transformer.py:33: UserWarning: Fail to import ``MultiScaleDeformableAttention`` from ``mmcv.ops.multi_scale_deform_attn``, You should install ``mmcv-full`` if you need this module.
#   warnings.warn('Fail to import ``MultiScaleDeformableAttention`` from '
# fatal: not a git repository (or any of the parent directories): .git
# 2024-03-10 06:21:42,023 - mmcls - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# CUDA available: True
# GPU 0: Tesla V100-SXM2-16GB
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 12.2, V12.2.140
# GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PyTorch: 2.1.0+cu121
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...
